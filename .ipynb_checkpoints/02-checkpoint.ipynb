# %%
from PIL import Image

# %%
dir = 'D:/Hinh_anh/01.JPG'

# %%
print(dir)
# Out:
# D:/Hinh_anh/01.JPG

# %%
img01 = Image.open(dir)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=762x750>
