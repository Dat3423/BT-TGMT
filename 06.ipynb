# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
my_path = 'D:/Hinh_anh/05.JPG'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=365x261>

# %%
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=365x261>

# %%
red_band, green_band, blue_band = img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=365x261>
# <PIL.Image.Image image mode=L size=365x261>
# <PIL.Image.Image image mode=L size=365x261>

# %%
merged_image =  Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=365x261>
