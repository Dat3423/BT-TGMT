# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
my_path = 'D:/Hinh_anh/05.JPG'
im = Image.open(my_path)
plt.imshow(im)

# %%
im_gray = im.convert('L')
plt.imshow(im_gray, cmap='gray')

# %%
im_array = np.array(im_gray)
print(im_array)
# Out:
# [[ 78  78  78 ... 186 197 194]
#  [ 78  78  77 ... 193 194 190]
#  [ 77  77  77 ... 219 209 195]
#  ...
#  [ 16  22  37 ...  14  13  13]
#  [ 15  14  19 ...  14  13  13]
#  [ 21  14  14 ...  14  13  12]]

# %%
plt.figure()
plt.hist(im_array.flatten(), bins=128)
plt.title('Biểu đồ Histogram của ảnh')
plt.xlabel('Giá trị của pixel')
plt.ylabel('Số lượng')
plt.show()

# %%
plt.figure()
plt.gray()
plt.contour(im_gray, origin="image")
plt.show()

# %%
my_path = 'D:/Hinh_anh/03.JPG'
im = Image.open(my_path).convert("L")
plt.imshow(im)
plt.figure()
plt.gray()
plt.contour(im, origin="image")
plt.axis('equal')
plt.show()
